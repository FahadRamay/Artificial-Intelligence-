# %%
from collections import deque


graph={
'a':['b','c'],
 'b':['d'],
    'c':[],
    'd':[]
}
start='a'
visited=set()

queue=deque([start])
while queue:
    node=(queue.popleft())
    if node not in visited:
        print(node)
        visited.add(node)
        for i in graph[node]:
          if i not in visted:
            queue.append(i)
# Out:
# a
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 20
#      18 visited.add(node)
#      19 for i in graph[node]:
# ---> 20   if i not in visted:
#      21     queue.append(i)
#
# NameError: name 'visted' is not defined
