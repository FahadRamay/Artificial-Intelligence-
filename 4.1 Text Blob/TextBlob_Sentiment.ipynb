# %%
from textblob import TextBlob
text= input("Enter Comment")
blob=TextBlob(text)
print("Sentiment Analysis for ", text, blob.sentiment)
# Out:
# Enter Comment this is best watch
# Sentiment Analysis for  this is best watch Sentiment(polarity=1.0, subjectivity=0.3)

# %%
pip install textblob
# Out:
# Collecting textblob
#   Downloading textblob-0.18.0.post0-py3-none-any.whl.metadata (4.5 kB)
# Collecting nltk>=3.8 (from textblob)
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: click in c:\users\cui\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>=3.8->textblob) (8.1.7)
# Collecting joblib (from nltk>=3.8->textblob)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\cui\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>=3.8->textblob) (2024.9.11)
# Requirement already satisfied: tqdm in c:\users\cui\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>=3.8->textblob) (4.66.5)
# Requirement already satisfied: colorama in c:\users\cui\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from click->nltk>=3.8->textblob) (0.4.6)
# Downloading textblob-0.18.0.post0-py3-none-any.whl (626 kB)
#    ---------------------------------------- 0.0/626.3 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/626.3 kB ? eta -:--:--
#    --------------------------------- ------ 524.3/626.3 kB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 626.3/626.3 kB 1.5 MB/s eta 0:00:00
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 1.5 MB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.5 MB 1.8 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.3/1.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.3/1.5 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 1.1 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Installing collected packages: joblib, nltk, textblob
# Successfully installed joblib-1.4.2 nltk-3.9.1 textblob-0.18.0.post0
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob
text="i like this product which is super cool"
result=TextBlob(text)
print(result.sentiment)
# Out:
# Sentiment(polarity=0.3416666666666667, subjectivity=0.6583333333333333)
