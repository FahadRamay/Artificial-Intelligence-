# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer
# Load pre-trained model and tokenizer
model_name = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Encode the input prompt
prompt = "what are dogs?"
input_ids = tokenizer.encode(prompt, return_tensors='pt')

# Generate output
output = model.generate(
    input_ids,
    max_length=100,
    top_p=0.95,
    top_k=50,
    temperature=1,
    pad_token_id=tokenizer.eos_token_id,   
)
# Decode the generated text
generated_text = tokenizer.decode(output[0],skip_special_tokens=True)
# Print the generated text
print(generated_text)
# Out:
# what are dogs?
#
# The answer is that dogs are not a natural part of our environment. They are part of our environment. They are part of our environment. They are part of our environment. They are part of our environment. They are part of our environment. They are part of our environment. They are part of our environment. They are part of our environment. They are part of our environment. They are part of our environment. They are part of our environment. They are part
