# %%
model = YOLO("koushik-ai/yolov8-license-plate-detection/best.pt")
results = model("lic.jpg")
results[0].show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model = YOLO("koushik-ai/yolov8-license-plate-detection/best.pt")
#       2 results = model("lic.jpg")
#       3 results[0].show()
#
# NameError: name 'YOLO' is not defined
