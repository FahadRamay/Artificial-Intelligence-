# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50, imagenet_utils
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Load the pretrained ResNet50 model
model = ResNet50(weights='imagenet')

# Load and preprocess an example image
image_path = 'catt.jpg'
try:
    img = load_img(image_path, target_size=(224, 224))
except FileNotFoundError:
    print("File NOT FOUND ")
    exit()
x = img_to_array(img)
x = tf.expand_dims(x, axis=0)
x = imagenet_utils.preprocess_input(x)
# Predict and decode the predictions
predictions = model.predict(x)
decoded_predictions = imagenet_utils.decode_predictions(predictions, top=5)[0]
print('Predicted:')
for (imagenet_id, label, score) in decoded_predictions:
    print(f'{label}: {score:.2f}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# Predicted:
# Egyptian_cat: 0.86
# tiger_cat: 0.05
# tabby: 0.05
# lynx: 0.03
# cougar: 0.00

# %%
import tensorflow as tf
from tensorflow.keras.applications import ResNet50, imagenet_utils
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Load the pretrained ResNet50 model
model = ResNet50(weights='imagenet')

# Load and preprocess an example image
image_path = 'catt.jpg'
try:
    img = load_img(image_path, target_size=(224, 224))
except FileNotFoundError:
    print("File NOT FOUND ")
    exit()

x = img_to_array(img)
x = tf.expand_dims(x, axis=0)
x = imagenet_utils.preprocess_input(x)

# Predict and decode the predictions
predictions = model.predict(x)
decoded_predictions = imagenet_utils.decode_predictions(predictions, top=5)[0]

# Print the top predictions
print('Predicted:')
for (imagenet_id, label, score) in decoded_predictions:
    print(f'{label}: {score:.2f}')
# Out:
# A local file was found, but it seems to be incomplete or outdated because the auto file hash does not match the original value of 2cb95161c43110f7111970584f804107 so we will re-download the data.
# ...
#   1974272/102967424 ━━━━━━━━━━━━━━━━━━━━ 1:22:04 49us/step
