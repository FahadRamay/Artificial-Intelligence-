# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt") 

results = model("obj.jpg")

results[0].show()
# Out:
# image 1/1 C:\Users\H.T\Desktop\AI Lab\5.0 image vision\yolo\obj.jpg: 256x640 18 cars, 3 buss, 1 truck, 266.0ms
# Speed: 10.5ms preprocess, 266.0ms inference, 33.4ms postprocess per image at shape (1, 3, 256, 640)

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt") 


model.predict(source=0, show=True)
# Out:
# 1/1: 0... Success  (inf frames of shape 640x480 at 30.00 FPS)
#
# WARNING
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 480x640 1 person, 1 laptop, 1 book, 263.4ms
# 0: 480x640 1 person, 1 laptop, 201.6ms
# 0: 480x640 1 person, 1 laptop, 205.3ms
# 0: 480x640 1 person, 1 laptop, 1 book, 204.7ms
# 0: 480x640 1 person, 1 laptop, 179.0ms
# 0: 480x640 1 person, 1 laptop, 1 book, 184.4ms
# 0: 480x640 1 person, 1 laptop, 1 book, 202.2ms
# 0: 480x640 1 person, 1 laptop, 1 book, 174.5ms
# ...
