# %%
import streamlit as st
st.title("Text Sentiment Analysis")
# Out:
# 2024-09-16 14:58:25.091
# ...
#   command:
#
#     streamlit run C:\Users\CUI\AppData\Local\Programs\Python\Python312\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()
