# %%
for i in range(5):
    for j in range(3):
        print("for 1st loop =", i, "for 2nd loop =", j)
# Out:
# for 1st loop = 0 for 2nd loop = 0
# for 1st loop = 0 for 2nd loop = 1
# for 1st loop = 0 for 2nd loop = 2
# for 1st loop = 1 for 2nd loop = 0
# for 1st loop = 1 for 2nd loop = 1
# for 1st loop = 1 for 2nd loop = 2
# for 1st loop = 2 for 2nd loop = 0
# for 1st loop = 2 for 2nd loop = 1
# for 1st loop = 2 for 2nd loop = 2
# for 1st loop = 3 for 2nd loop = 0
# for 1st loop = 3 for 2nd loop = 1
# for 1st loop = 3 for 2nd loop = 2
# for 1st loop = 4 for 2nd loop = 0
# for 1st loop = 4 for 2nd loop = 1
# for 1st loop = 4 for 2nd loop = 2

# %%
import numpy as np
import matplotlib.pyplot as plt
x=[2,3,4,5,6]
y=[3,5,6,8,9]

plt.title('Graph in AI lab')
plt.xlabel('x-axis')
plt.ylabel('y-axis')

plt.plot(x,y,  color='r', linestyle='--', marker='s', label='direction along axis')
plt.legend()
plt.show()

# %%
import importer
importer.function(2,3)
# Out:
# 5

# %%
import numpy as np
import matplotlib.pyplot as plt
x=[2,3,4,5,6]
y=[3,4,5,7,8]
plt.plot(x,y, linewidth='4',marker='s', color='red', linestyle='--', label='x vs y')
plt.legend()
plt.fill_between(x,y, color='lightgreen')
plt.grid(true)
plt.show()
