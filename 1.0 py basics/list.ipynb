# %%
List = [2,4,6]
print("Blank List: ")
print(List)
# Out:
# Blank List:
# 2

# %%
List = [["Geeks"], ["For", "Geeks"]]
print("List Items: ")
print(List[0])
print(List[1])
# Out:
# List Items:
# ['Geeks']
# ['For', 'Geeks']

# %%
List = []
print("Initial blank List: ")
print(List)
# Addition of Elements
# in the List
List.append(1)
List.append(2)
List.append(4)
print("\nList after Addition of Three elements: ")
print(List)
# Out:
# Initial blank List:
# []
#
# List after Addition of Three elements:
# [1, 2, 4]

# %%
# Initial blank List
List = []
print("Initial blank List: ")
print(List)

# Adding elements to the List using an iterator
for i in range(1, 5):
    List.append(i)

print("\nList after Addition of elements from 1-3: ")
print(List)

# Adding a Tuple to the List
List.append(5)

print("\nList after Addition of a Tuple: ")
print(List)
# Out:
# Initial blank List:
# []
#
# List after Addition of elements from 1-3:
# [1, 2, 3, 4]
#
# List after Addition of a Tuple:
# [1, 2, 3, 4, 5]

# %%
# Initial lists
List1 = [1, 2, 3]
List2 = [4, 5, 6]

# Adding List2 to List1 using extend
List1.extend(List2)

print("List after Addition using extend: ")
print(List1)
# Out:
# List after Addition using extend:
# [1, 2, 3, 4, 5, 6]

# %%
# Out:
# Target 7 found at index 2

# %%
list = [10, 5, 7, 2, 8, 12]
target = 7
for i in range(len(list)):
 if target == list[i]:
    print("Element found")
    break
else:
    print("Element not found")
# Out:
# Element found
