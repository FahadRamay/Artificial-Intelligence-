# %%
num=8
a,b=0,1
for i in range(num):
    print(a, end="-")
    a,b=b,a+b
# Out:
# 0-1-1-2-3-5-8-13-

# %%
dic={"name":"fahad",
    "age":20,
    "email":"fahad.amin@cuisahiwal.edu.pk"}
question=input("ask me about myself")
answer=dic.get(question,"invalid")
print(answer)
# Out:
# ask me about myself ajdan
# invalid
